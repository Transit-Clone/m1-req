# %% [markdown]
# <a href="https://colab.research.google.com/github/Transit-Clone/m1-req/blob/main/Proposal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
